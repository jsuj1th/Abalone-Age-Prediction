# %% [markdown]
# ## Abalone Age Prediction

# %% [markdown]
# # Introduction
# ![Abalone](https://www.google.com/imgres?q=abalone&imgurl=https%3A%2F%2Fasc-aqua.org%2Fwp-content%2Fuploads%2F2023%2F03%2Fshutterstock_1916916224-1-2500x1250.jpg&imgrefurl=https%3A%2F%2Fasc-aqua.org%2Flearn-about-seafood-farming%2Ffarmed-abalone%2F&docid=u167HhoNl_SMuM&tbnid=SYe6-nGLacXqMM&vet=12ahUKEwiry87y-eaJAxWW_8kDHf37JuAQM3oECBYQAA..i&w=2500&h=1250&hcb=2&ved=2ahUKEwiry87y-eaJAxWW_8kDHf37JuAQM3oECBYQAA)
# <img src="...:image/jpeg;base64,..." alt="NO"/>

# %%
# !pip install ucimlrepo
# !pip install dython

from ucimlrepo import fetch_ucirepo 
import pandas as pd
import seaborn as sns
from dython import nominal
from dython import nominal
from matplotlib import pyplot as plt

# %%
  
abalone = fetch_ucirepo(id=1) 
  
X = abalone.data.features 
y = abalone.data.targets 
  
print(abalone.metadata) 
  
print(abalone.variables)
# Out:
# {'uci_id': 1, 'name': 'Abalone', 'repository_url': 'https://archive.ics.uci.edu/dataset/1/abalone', 'data_url': 'https://archive.ics.uci.edu/static/public/1/data.csv', 'abstract': 'Predict the age of abalone from physical measurements', 'area': 'Biology', 'tasks': ['Classification', 'Regression'], 'characteristics': ['Tabular'], 'num_instances': 4177, 'num_features': 8, 'feature_types': ['Categorical', 'Integer', 'Real'], 'demographics': [], 'target_col': ['Rings'], 'index_col': None, 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 1994, 'last_updated': 'Mon Aug 28 2023', 'dataset_doi': '10.24432/C55C7W', 'creators': ['Warwick Nash', 'Tracy Sellers', 'Simon Talbot', 'Andrew Cawthorn', 'Wes Ford'], 'intro_paper': None, 'additional_info': {'summary': 'Predicting the age of abalone from physical measurements.  The age of abalone is determined by cutting the shell through the cone, staining it, and counting the number of rings through a microscope -
# ...

# %%
print(type(abalone))
print(X)
print(y)
# Out:
# <class 'ucimlrepo.dotdict.dotdict'>
#      Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera_weight  Shell_weight
# 0             0.1010        0.1500
# 1             0.0485        0.0700
# 2             0.1415        0.2100
# ...

# %%
# df=pd.read_csv("abalone.data",header=None)
# df.head()
# dfs=sns.load_dataset("abalone.data")
# ax=sns.heatmap(dfs.corr,annot=True)
# import matplotlib.pyplot as plt
# Load the dataset
df = pd.read_csv("abalone.data", header=None)
df.columns = ['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight', 'Viscera weight', 'Shell weight', 'Rings']
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
associations = nominal.associations(df, nominal_columns='auto', plot=False)
plt.figure(figsize=(12, 10))
sns.heatmap(associations['corr'], annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Mixed Data Correlation Matrix')
plt.show()
